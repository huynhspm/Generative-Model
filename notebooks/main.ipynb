# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Diffusion

# %%
# !pip install hydra-core --upgrade
# !pip install pytorch_lightning
# !pip install opendatasets

# %%
# !python train.py

# %%
# !python inference.py
